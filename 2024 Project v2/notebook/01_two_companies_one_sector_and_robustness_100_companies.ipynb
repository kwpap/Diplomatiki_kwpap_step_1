# %%
import pandas as pd
import numpy as np
import sympy as sp
import gurobipy as gp
from gurobipy import GRB
import sys
import os
import tqdm
import time

# Get the current script's directory
current_dir = os.getcwd()

# Navigate to the target directory one up and two down
target_dir = os.path.abspath(os.path.join(current_dir, '..', 'src'))

# Add the target directory to sys.path
sys.path.append(target_dir)

# %%
# Select random seed
np.random.seed(0)

#Generate one sector
x = sp.symbols('x')
dummy_market = pd.DataFrame({
    'id': 1,
    'name': 'dummy_market',
    'permit_price': [2] # the price is fixed and is the market-clrearing price 
    # If permit price < 2.3 then it crushes
    })
dummy_sector = pd.DataFrame({
  'id': 1,
    'name': 'dummy_sector',
    'price_demand_function': [10 - 0.1*x]
    })

#Genarate two firms

dummy_firm1 = pd.DataFrame({
    'id': 1,
    'name': 'dummy_firm1',
    'sector_id': 1,
    'country': 'US',
    'production_cost_function': [x*0],
    'abatement_cost_function': [5*x**2],
    'emission_to_output_ratio': 1,
    'actual_output': 0,
    'emission': 0,
    'free_emission_multiplier': [0.1],
    'profit': 0
    })
dummy_firm2 = pd.DataFrame({
    'id': 2,
    'name': 'dummy_firm2',
    'sector_id': 1,
    'country': 'US',
    'production_cost_function': [x],
    'abatement_cost_function': [x**2*0.01],
    'emission_to_output_ratio': 1,
    'actual_output': 0,
    'emission': 0,
    'free_emission_multiplier': [0.1],
    'profit': 0
    })

# %%
type((x)*0.5)
# Out:
# sympy.core.mul.Mul

# %%
import sympy as sp
from gurobipy import Model, LinExpr, QuadExpr, GRB

def sympy_to_gurobi(sympy_expr, symbol_map):
    """
    Recursively convert a SymPy expression to a Gurobi expression.
    
    Parameters:
        sympy_expr (sp.Expr): SymPy expression to convert.
        symbol_map (dict): Mapping from SymPy symbols to Gurobi variables.
        
    Returns:
        Gurobi expression (LinExpr, QuadExpr, or constant).
    """
    if isinstance(sympy_expr, sp.Symbol):
        return symbol_map[sympy_expr]
    
    elif isinstance(sympy_expr, sp.Add):
        return sum(sympy_to_gurobi(arg, symbol_map) for arg in sympy_expr.args)
    
    elif isinstance(sympy_expr, sp.Mul):
            result = 1
            for arg in sympy_expr.args:
                result *= sympy_to_gurobi(arg, symbol_map)
            return result
    
    elif isinstance(sympy_expr, sp.Pow):
        base, exp = sympy_expr.args
        if exp == 2:
            base_expr = sympy_to_gurobi(base, symbol_map)
            return QuadExpr(base_expr * base_expr)
        else:
            raise ValueError("Non-quadratic powers are not supported by Gurobi.")
    
    elif isinstance(sympy_expr, sp.Number):
        return float(sympy_expr)
    
    else:
        raise ValueError(f"Unsupported SymPy expression: {sympy_expr}")


# Example usage
x, y = sp.symbols('x y')
sympy_expr = +3*x - 2*y**2 - 4*y 

# Create a Gurobi model
model = Model("example")
x_gurobi = model.addVar(name="x", lb=0, vtype=GRB.CONTINUOUS, ub = 10)
y_gurobi = model.addVar(name="y", lb=0, vtype=GRB.CONTINUOUS, ub = 10)

# Map SymPy symbols to Gurobi variables
symbol_map = {x: x_gurobi, y: y_gurobi}

# Convert SymPy expression to Gurobi expression
gurobi_expr = sympy_to_gurobi(sympy_expr, symbol_map)

# Set the objective and optimize
model.setObjective(gurobi_expr, GRB.MAXIMIZE)
model.optimize()

# Print the results
for v in model.getVars():
    print(f"{v.varName}: {v.X}")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-7700HQ CPU @ 2.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 0 rows, 2 columns and 0 nonzeros
# Model fingerprint: 0xcc5870d7
# Model has 1 quadratic objective term
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [3e+00, 4e+00]
#   QObjective range [4e+00, 4e+00]
#   Bounds range     [1e+01, 1e+01]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Barrier solved model in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective 3.00000000e+01
# x: 10.0
# y: 0.0

# %%
import sympy as sp

def taylor_approx(expr, var_list, point_dict=None, order=2):
    """
    Approximates the given expression using the first three Taylor series terms (up to quadratic) for non-linear terms.

    Parameters:
    expr (sympy.Expr): The sympy expression to approximate.
    var_list (list): A list of sympy symbols representing the variables for Taylor expansion.
    order (int): The highest order term to include in the Taylor series (default is 2 for quadratic).
    
    Returns:
    sympy.Expr: The approximated expression.
    """
    approx_expr = expr
    for var in var_list:
        # Perform Taylor expansion around var=point up to the specified order (default is 2)
        taylor_series = sp.series(approx_expr, var, point_dict[var], order+1).removeO()
        approx_expr =  taylor_series
    
    return approx_expr

# Example usage:
x, y = sp.symbols('x y')
expr = sp.sin(x) + x**3 + y**4
vars_to_expand = [x, y]
points = {x: 1, y: 1}

approx_expr = taylor_approx(expr, vars_to_expand, points)
print(approx_expr)
# Out:
# 4*y + (3 - sin(1)/2)*(x - 1)**2 + (x - 1)*(cos(1) + 3) + 6*(y - 1)**2 - 2 + sin(1)

# %%
def is_quadratic(expr, var_list): # Thelei allagi! Prepei sto trito paradeigma na girizei false!
    """
    Checks if the given sympy expression is quadratic in all specified variables.

    Parameters:
    expr (sympy.Expr): The sympy expression to check.
    var_list (list): A list of sympy symbols representing the variables.

    Returns:
    bool: True if the expression is quadratic, False otherwise.
    """
    for term in expr.as_ordered_terms():
        degree = max(term.as_poly(var).degree(var) for var in var_list if term.as_poly(var) is not None)
        #print(f" Degree: {degree}, Term: {term}")

        if degree > 2:
            return False
    return True

# Example usage:
x, y = sp.symbols('x y')
expr1 = x**2 + y**2 + x*y + x + y + 1  # Quadratic
expr2 = x**3 + y**2 + sp.exp(x) # Not quadratic

print(is_quadratic(expr1, [x, y]))  # Output: True
print(is_quadratic(expr2, [x, y]))  # Output: False

em, out = sp.symbols('em out')
exp = -5*em + out*(99.0 - 0.1*out) + out - 10*(-em + out)**2 + em**2*out
print(is_quadratic(exp, [em, out]))
# Out:
# True
# False
# True

# %%
import sympy as sp
import gurobipy as gp
from gurobipy import GRB

# Assuming x is already defined as a symbol
x = sp.symbols('x')

# Print the function of abatement cost evaluated at x = 5, using sympy
print("Abatement cost function evaluated at 5:{}".format(dummy_firm1['abatement_cost_function'][0].subs(x, 5).evalf()))  # 74.20...

# Calculate the output of a firm taking the decisions of the rest of the firms as given
def calculate_output(firm, firms, dummy_market, dummy_sector, lp_counter = 0):
    # Calculate the output of the firm

    # Sum of all other outputs
    sum_other_outputs = 0
    for i in range(len(firms)):
        if firms[i]['id'][0] != firm['id'][0]:
            sum_other_outputs += firms[i]['actual_output'][0]
    
    #Get the price of the permits
    permit_price = dummy_market['permit_price'][0]
    # Get the price demand function of the sector
    price_demand_function = dummy_sector['price_demand_function'][0]
    # Get the abatement cost function of the firm
    abatement_cost_function = firm['abatement_cost_function'][0]
    # Get the production cost function of the firm
    production_cost_function = firm['production_cost_function'][0]
    # Get the free emission multiplier of the firm
    free_emission_multiplier = firm['free_emission_multiplier'][0]


    out, em = sp.symbols('out em')


    # Calculate the output of the firm


    #print("Price to demand Function: {}".format(price_demand_function.subs(x, sum_other_outputs + out)))
    income = (price_demand_function.subs(x, sum_other_outputs + out) - production_cost_function.subs(x, out))*out
    abatement = -abatement_cost_function.subs(x, out - em)
    trading = - permit_price * (em -free_emission_multiplier * out)
    profit_expr = income + abatement + trading
    print(f"The profit expr: {profit_expr}")
    # if(is_quadratic(profit_expr, [out, em])):
    #     #print("The profit expr is quadratic {}".format(profit_expr))
    #     second_order = profit_expr
    # else:
    #     second_order = taylor_approx(profit_expr, [out, em], {out :1, em :1}, order=2) #ALLAGI ME KANONIKA NOUMERA
    #     print(f"The profit expr: {profit_expr} \nis turned to: {second_order}")
    second_order = profit_expr
    m = gp.Model("firm")
    output = m.addVar(vtype=GRB.CONTINUOUS, name="output", lb=0)
    emission = m.addVar(vtype=GRB.CONTINUOUS, name="emission", lb=0)
    symbol_map = {out: output, em: emission}
    profit = sympy_to_gurobi(second_order, symbol_map)
    m.setObjective(profit, GRB.MAXIMIZE)
    gur_abatement = sympy_to_gurobi(abatement, symbol_map)
    m.addConstr(emission <= output)
    m.Params.LogToConsole = 0
    if lp_counter > 0:
        m.write("old{}.lp".format(lp_counter))
    m.optimize()


    # print("income: {}".format(income.subs(out, output.X).subs(em, emission.X)))
    # print("abatement: {}".format(abatement.subs(out, output.X).subs(em, emission.X)))
    # print("trading: {}".format(trading.subs(out, output.X).subs(em, emission.X)))
    # for v in m.getVars():
    #     print(f"{v.varName}: {v.X}")
    # return sum_other_outputs
    return output.X, emission.X, profit_expr.subs(out, output.X).subs(em, emission.X).evalf()

print(calculate_output(dummy_firm1, [dummy_firm1, dummy_firm2], dummy_market, dummy_sector))
# Out:
# Abatement cost function evaluated at 5:125.000000000000
# The profit expr: -2*em + out*(10 - 0.1*out) + 0.2*out - 5*(-em + out)**2
# (41.00000000009346, 40.79999999430374, 168.300000000000)

# %%
import math
firms = [dummy_firm1, dummy_firm2]

def optimize_them_all(firms, dummy_market, dummy_sector, print_output=True,print_diff=False):
    repeat = True
    
    while repeat:
        lp_counter = 1
        max_diff = 0
        repeat = False
        for firm in firms:
            output, emission, profit = calculate_output(firm, firms, dummy_market, dummy_sector, lp_counter= lp_counter)
            lp_counter += 1
            #print("Firm {} has 'output - firm['actual_output'][0]': {:5f} and 'emission - firm['emission'][0]': {:5f}".format(firm['name'][0], output - firm['actual_output'][0], emission - firm['emission'][0]))
            if abs(output - firm['actual_output'][0])>0.01 or abs(emission - firm['emission'][0])>0.01:
                repeat = True
            max_diff = max(max_diff, abs(output - firm['actual_output'][0]), abs(emission - firm['emission'][0]))
            firm['actual_output'] = output
            firm['emission'] = emission
            firm['profit'] = profit
            if(print_output):
                print("Firm {} has output: {:5f} and emission: {:5f} and profit: {:2f}".format(firm['name'][0], firm['actual_output'][0], firm['emission'][0], profit))
        if(print_diff): 
            sys.stdout.write("\rMax diff: {:5f}".format(max_diff))
            sys.stdout.flush()
optimize_them_all(firms, dummy_market, dummy_sector)
# Out:
# The profit expr: -2*em + out*(10 - 0.1*out) + 0.2*out - 5*(-em + out)**2
# Firm dummy_firm1 has output: 41.000000 and emission: 40.800000 and profit: 168.300000000000
# The profit expr: -2*em + out*(5.89999999999065 - 1.1*out) + 0.2*out - 0.01*(-em + out)**2
# Firm dummy_firm2 has output: 2.747748 and emission: 0.000000 and profit: 8.38063063043580
# The profit expr: -2*em + out*(9.72522522520855 - 0.1*out) + 0.2*out - 5*(-em + out)**2
# Firm dummy_firm1 has output: 39.626126 and emission: 39.426126 and profit: 157.222987175705
# The profit expr: -2*em + out*(6.03738738739054 - 1.1*out) + 0.2*out - 0.01*(-em + out)**2
# Firm dummy_firm2 has output: 2.809634 and emission: 0.000000 and profit: 8.76238770712769
# The profit expr: -2*em + out*(9.71903660415794 - 0.1*out) + 0.2*out - 5*(-em + out)**2
# Firm dummy_firm1 has output: 39.595183 and emission: 39.395183 and profit: 156.977851844983
# The profit expr: -2*em + out*(6.04048169791447 - 1.1*out) + 0.2*out - 0.01*(-em + out)**2
# Firm dummy_firm2 has output: 2.811028 and emission: 0.000000 and profit: 8.77108374353024
# The profit expr: -2*em + out*(9.71889722080107 - 0.1*out) + 0.2*out - 5*(-em + out)**2
# Firm dummy_firm1 has output: 39.594486 and emission: 39.394486 and profit: 156.972332984027
# The profit expr: -2*em + out*(6.04055138958781 - 1.1*out) + 0.2*out - 0.01*(-em + out)**2
# Firm dummy_firm2 has output: 2.811059 and emission: 0.000000 and profit: 8.77127964985477

# %%
# Select random seed
import numpy as np
np.random.seed(0)

#Let's create a function that will generate the dataframes for the market, sector and 10 firms
x = sp.symbols('x')
def generate_dataframes(number_of_firms = 10):
    #Generate the market
    market = pd.DataFrame({
        'id': 1,
        'name': 'dummy_market',
        'permit_price': [5] # the price is fixed and is the market-clrearing price 
        # If permit price < 2.3 then it crushes
        })
    #Generate the sector
    sector = pd.DataFrame({
    'id': 1,
        'name': 'dummy_sector',
        'price_demand_function': [100 - 0.1*x]
        })
    #Generate the firms
    firms = []
    for i in range(number_of_firms):
        firm = pd.DataFrame({
            'id': i,
            'name': f'dummy_firm{i}',
            'sector_id': 1,
            'country': 'US',
            'production_cost_function': [x*0],
            'abatement_cost_function': [np.random.rand()*0.5 *x**2],
            'emission_to_output_ratio': 1,
            'actual_output': np.random.randint(1, 2),
            'emission': 0,
            'free_emission_multiplier': [np.random.rand()],
            'profit': 0
            })
        firms.append(firm)
    return market, sector, firms
market, sector, firms = generate_dataframes()

for firm in firms:
    
    firm["actual_output"] = np.random.randint(100, 20000)
optimize_them_all(firms, market, sector)

#Save the firms dataframe to a csv file
firms_df = pd.concat(firms)
firms_df.to_csv('firms2.csv', index=False)
# Out:
# The profit expr: -5*em + out*(-0.1*out - 10233.1) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 0.000000 and emission: 0.000000 and profit: -0.000000690479465362813
# The profit expr: -5*em + out*(-0.1*out - 9203.10000000001) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 0.000000 and emission: 0.000000 and profit: -0.00000118518189861212
# The profit expr: -5*em + out*(-0.1*out - 9117.60000000002) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 0.000000 and emission: 0.000000 and profit: -0.00000114318452001500
# The profit expr: -5*em + out*(-0.1*out - 9027.90000000003) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 0.000000 and emission: 0.000000 and profit: -0.00000118811310675439
# The profit expr: -5*em + out*(-0.1*out - 7313.60000000005) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 0.000000 and emission: 0.000000 and profit: -0.00000000454176918195434
# The profit expr: -5*em + out*(-0.1*out - 6981.70000000005) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 0.000000 and emission: 0.000000 and profit: -0.00000000537370442660200
# The profit expr: -5*em + out*(-0.1*out - 5447.10000000005) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 0.000000 and emission: 0.000000 and profit: -0.000000532541868420113
# The profit expr: -5*em + out*(-0.1*out - 3805.00000000006) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 0.000000 and emission: 0.000000 and profit: -0.000000559451096923228
# The profit expr: -5*em + out*(-0.1*out - 1822.90000000007) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 0.000000 and emission: 0.000000 and profit: -0.000000000893456782789560
# The profit expr: -5*em + out*(99.99999999993 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 496.750304 and emission: 490.324863 and profit: 24692.1500247444
# The profit expr: -5*em + out*(50.3249696293668 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 244.504582 and emission: 235.394019 and profit: 6001.02548435755
# The profit expr: -5*em + out*(25.8745113987578 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 117.994637 and emission: 109.699508 and profit: 1413.01124856003
# The profit expr: -5*em + out*(14.0750477419001 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 61.522592 and emission: 49.720530 and profit: 408.008080702857
# The profit expr: -5*em + out*(7.9227885882953 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 36.908268 and emission: 25.481974 and profit: 164.787758665437
# The profit expr: -5*em + out*(4.23196179214814 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 5.745847 and emission: 0.557310 and profit: 16.2728184854586
# The profit expr: -5*em + out*(3.65737709833563 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 6.509258 and emission: 0.193935 and profit: 20.0253541787028
# The profit expr: -5*em + out*(3.00645124943478 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 13.172172 and emission: 4.370046 and profit: 39.3559279370878
# The profit expr: -5*em + out*(1.68923402899676 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 7.839844 and emission: 0.000000 and profit: 8.32936636951135
# The profit expr: -5*em + out*(0.905249587348649 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 23.015102 and emission: 0.000000 and profit: 58.3242817336032
# The profit expr: -5*em + out*(48.2787697867085 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 238.144153 and emission: 231.718712 and profit: 5687.32734521063
# The profit expr: -5*em + out*(48.9148127533571 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 237.453798 and emission: 228.343235 and profit: 5661.20702244005
# The profit expr: -5*em + out*(36.9688966176172 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 173.466563 and emission: 165.171434 and profit: 3029.80265887374
# The profit expr: -5*em + out*(25.77449950493 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 120.019850 and emission: 108.217789 and profit: 1469.98160160549
# The profit expr: -5*em + out*(17.463341265945 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 84.611031 and emission: 73.184738 and profit: 744.468396875959
# The profit expr: -5*em + out*(9.57682282482845 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 32.470152 and emission: 27.281615 and profit: 118.402420495426
# The profit expr: -5*em + out*(6.98073346426017 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 23.126040 and emission: 16.810716 and profit: 69.2696836412680
# The profit expr: -5*em + out*(5.98534665319897 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 28.066649 and emission: 19.264523 and profit: 100.778995741054
# The profit expr: -5*em + out*(3.9626661720864 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 16.227777 and emission: 0.000000 and profit: 35.6874182634749
# The profit expr: -5*em + out*(4.64139865828353 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 39.980755 and emission: 0.000000 and profit: 176.005238267471
# The profit expr: -5*em + out*(24.4577383807117 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 119.038996 and emission: 112.613555 and profit: 1433.09184913925
# The profit expr: -5*em + out*(36.2992186123487 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 174.375827 and emission: 165.265264 and profit: 3063.46931939002
# The profit expr: -5*em + out*(36.2082921565481 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 169.663540 and emission: 161.368411 and profit: 2899.30951533143
# The profit expr: -5*em + out*(31.2439231559162 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 147.366969 and emission: 135.564907 and profit: 2201.20749738972
# The profit expr: -5*em + out*(24.9683294302203 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 122.135972 and emission: 110.709678 and profit: 1520.28530408419
# The profit expr: -5*em + out*(16.0017474226337 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 64.594775 and emission: 59.406238 and profit: 430.219839602405
# The profit expr: -5*em + out*(11.8548739457664 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 47.496743 and emission: 41.181419 and profit: 241.382366501799
# The profit expr: -5*em + out*(9.91186459626159 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 47.699239 and emission: 38.897113 and profit: 249.527055411012
# The profit expr: -5*em + out*(6.7647183874075 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 26.566077 and emission: 0.000000 and profit: 95.6427252415725
# The profit expr: -5*em + out*(8.10618619423148 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 55.714171 and emission: 0.000000 and profit: 341.786532177603
# The profit expr: -5*em + out*(14.4386686689887 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 68.943647 and emission: 62.518206 and profit: 491.386248432805
# The profit expr: -5*em + out*(24.981886685983 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 117.789168 and emission: 108.678605 and profit: 1410.20520762360
# The profit expr: -5*em + out*(30.169323962825 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 139.468699 and emission: 131.173570 and profit: 1965.88963358904
# The profit expr: -5*em + out*(30.9591508845461 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 145.943107 and emission: 134.141046 and profit: 2159.44420913115
# The profit expr: -5*em + out*(28.5784373766711 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 140.186512 and emission: 128.760218 and profit: 1993.79154622753
# The profit expr: -5*em + out*(21.0192636947617 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 89.682356 and emission: 84.493819 and profit: 817.263848532555
# The profit expr: -5*em + out*(16.8007023225819 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 72.225885 and emission: 65.910561 and profit: 537.446150298095
# The profit expr: -5*em + out*(14.3480377557758 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 69.880105 and emission: 61.077978 and profit: 510.328219672779
# The profit expr: -5*em + out*(10.0166350168745 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 38.564173 and emission: 0.000000 and profit: 201.541797798018
# The profit expr: -5*em + out*(11.7316347743333 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 72.177140 and emission: 0.000000 and profit: 573.618217036002
# The profit expr: -5*em + out*(11.4082855251018 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 53.791731 and emission: 47.366291 and profit: 305.418637527909
# The profit expr: -5*em + out*(17.808029150856 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 81.919880 and emission: 72.809317 and profit: 693.863079993041
# The profit expr: -5*em + out*(23.5629110983996 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 106.436635 and emission: 98.141506 and profit: 1153.61355109867
# The profit expr: -5*em + out*(27.5135583166469 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 128.715144 and emission: 116.913083 and profit: 1686.26399381642
# The profit expr: -5*em + out*(28.660695065947 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 140.597800 and emission: 129.171507 and profit: 2005.33988058292
# The profit expr: -5*em + out*(23.5691506754631 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 102.431791 and emission: 97.243254 and profit: 1062.19853066477
# The profit expr: -5*em + out*(20.5485600013388 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 90.965173 and emission: 84.649849 and profit: 843.254579476987
# The profit expr: -5*em + out*(18.4400531749094 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 90.340182 and emission: 81.538055 and profit: 838.140161220029
# The profit expr: -5*em + out*(13.2624523204777 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 50.539765 and emission: 0.000000 and profit: 346.149350942943
# The profit expr: -5*em + out*(15.4261897264358 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 88.953917 and emission: 0.000000 and profit: 871.271987695996
# The profit expr: -5*em + out*(11.9099712021083 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 56.300160 and emission: 49.874719 and profit: 333.034399974678
# The profit expr: -5*em + out*(14.4719432217975 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 65.239450 and emission: 56.128887 and profit: 448.394994618305
# The profit expr: -5*em + out*(18.5916617016579 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.580388 and emission: 73.285259 and profit: 686.273794642543
# The profit expr: -5*em + out*(23.3051373343242 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 107.673039 and emission: 95.870978 and profit: 1188.85349725023
# The profit expr: -5*em + out*(26.5976134194222 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 130.282392 and emission: 118.856098 and profit: 1725.91590384112
# The profit expr: -5*em + out*(23.8125533425537 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 103.648805 and emission: 98.460268 and profit: 1087.27881401960
# The profit expr: -5*em + out*(22.5441901742595 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 100.943324 and emission: 94.628000 and profit: 1034.74377286945
# The profit expr: -5*em + out*(21.4838759709344 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 105.559296 and emission: 96.757169 and profit: 1136.28180911091
# The profit expr: -5*em + out*(15.9819229381168 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 60.573377 and emission: 0.000000 and profit: 497.233814567457
# The profit expr: -5*em + out*(18.8199768576619 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 104.364923 and emission: 0.000000 and profit: 1199.31348263127
# The profit expr: -5*em + out*(14.0135005323479 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 66.817806 and emission: 60.392366 and profit: 462.525526343902
# The profit expr: -5*em + out*(13.8556649223896 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 62.158059 and emission: 53.047496 and profit: 409.138834508455
# The profit expr: -5*em + out*(15.7978978535846 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 67.611569 and emission: 59.316440 and profit: 477.870246800883
# The profit expr: -5*em + out*(19.8040449191275 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 90.167577 and emission: 78.365516 and profit: 842.524355590973
# The profit expr: -5*em + out*(23.8155263885617 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 116.371957 and emission: 104.945663 and profit: 1382.80897100207
# The profit expr: -5*em + out*(22.5432111606707 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 97.302094 and emission: 92.113557 and profit: 959.741088069953
# The profit expr: -5*em + out*(22.907334169781 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 102.759044 and emission: 96.443720 and profit: 1071.73041872276
# The profit expr: -5*em + out*(23.187359366708 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 114.076713 and emission: 105.274586 and profit: 1323.35495599537
# The profit expr: -5*em + out*(17.8370258255719 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 67.417865 and emission: 0.000000 and profit: 615.952276023890
# The profit expr: -5*em + out*(21.5317316437948 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 116.678857 and emission: 0.000000 and profit: 1499.02174657222
# The profit expr: -5*em + out*(16.5456265951952 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 79.478437 and emission: 73.052996 and profit: 647.745791305744
# The profit expr: -5*em + out*(14.8135888041099 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 66.947678 and emission: 57.837115 and profit: 470.975568854742
# The profit expr: -5*em + out*(14.8799778704097 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 63.021969 and emission: 54.726840 and profit: 417.914679405006
# The profit expr: -5*em + out*(17.5945387199397 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 79.120046 and emission: 67.317985 and profit: 655.503328421266
# The profit expr: -5*em + out*(21.3197297735393 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 103.892974 and emission: 92.466680 and profit: 1107.94073659078
# The profit expr: -5*em + out*(20.6606417622172 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 87.889247 and emission: 82.700710 and profit: 785.423312775562
# The profit expr: -5*em + out*(22.1476214683196 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 98.960480 and emission: 92.645157 and profit: 995.105976397310
# The profit expr: -5*em + out*(23.6592447138641 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 116.436140 and emission: 107.634013 and profit: 1377.74277466526
# The profit expr: -5*em + out*(18.7574172399615 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 70.965319 and emission: 0.578530 and profit: 679.574616811111
# The profit expr: -5*em + out*(23.3287710527668 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 124.839117 and emission: 0.000000 and profit: 1716.03040505497
# The profit expr: -5*em + out*(18.7927030223881 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 90.713819 and emission: 84.288378 and profit: 838.963294018455
# The profit expr: -5*em + out*(16.4160889585654 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 74.960179 and emission: 65.849616 and profit: 584.679250340981
# The profit expr: -5*em + out*(15.222267956051 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 64.733419 and emission: 56.438290 and profit: 439.779380803126
# The profit expr: -5*em + out*(16.6609306631663 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 74.452006 and emission: 62.649945 and profit: 583.815275634507
# The profit expr: -5*em + out*(19.6050274376415 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 95.319462 and emission: 83.893168 and profit: 937.145721834780
# The profit expr: -5*em + out*(18.8620058950373 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 78.896067 and emission: 73.707530 and profit: 635.430288631275
# The profit expr: -5*em + out*(20.8684471839963 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 92.564609 and emission: 86.249285 and profit: 872.608991912150
# The profit expr: -5*em + out*(23.2556002452806 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 114.417917 and emission: 105.615791 and profit: 1331.15129314466
# The profit expr: -5*em + out*(18.9103403994953 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 71.729934 and emission: 1.343146 and profit: 690.485321294671
# The profit expr: -5*em + out*(24.2212586490635 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 128.891856 and emission: 0.000000 and profit: 1829.25627795629
# The profit expr: -5*em + out*(20.4034549738432 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 98.767579 and emission: 92.342138 and profit: 991.567059326462
# The profit expr: -5*em + out*(18.0227150115208 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 82.993309 and emission: 73.882746 and profit: 711.565344964775
# The profit expr: -5*em + out*(16.1967260253475 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 69.605710 and emission: 61.310581 and profit: 505.233304968973
# The profit expr: -5*em + out*(16.6813556694285 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 74.554131 and emission: 62.752070 and profit: 585.337001278406
# The profit expr: -5*em + out*(18.7578887728243 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 91.083769 and emission: 79.657475 and profit: 858.191029682570
# The profit expr: -5*em + out*(17.5391186290381 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 72.281631 and emission: 67.093094 and profit: 535.434762466131
# The profit expr: -5*em + out*(19.5674164088352 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 86.059455 and emission: 79.744131 and profit: 756.411289719323
# The profit expr: -5*em + out*(22.4032626234061 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 110.156229 and emission: 101.354103 and profit: 1235.44479626662
# The profit expr: -5*em + out*(18.5606331649944 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 70.087648 and emission: 0.000001 and profit: 665.702274889609
# The profit expr: -5*em + out*(24.4410539536402 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 129.889934 and emission: 0.000000 and profit: 1857.69578912112
# The profit expr: -5*em + out*(21.3288183783607 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 103.394396 and emission: 96.968955 and profit: 1085.10370566898
# The profit expr: -5*em + out*(19.2887097402603 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 89.323283 and emission: 80.212720 and profit: 820.641293587027
# The profit expr: -5*em + out*(17.3169524243647 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 75.206842 and emission: 66.911713 and profit: 586.344726461736
# The profit expr: -5*em + out*(17.2516813720664 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 77.405760 and emission: 65.603698 and profit: 628.670317042391
# The profit expr: -5*em + out*(18.619482291734 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 90.391736 and emission: 78.965443 and profit: 845.632336631961
# The profit expr: -5*em + out*(16.808471755492 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 68.628397 and emission: 63.439860 and profit: 483.957026811090
# The profit expr: -5*em + out*(18.5515775844813 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.980261 and emission: 74.664937 and profit: 671.568575381653
# The profit expr: -5*em + out*(21.4691744002951 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 105.485788 and emission: 96.683662 and profit: 1134.73046200733
# The profit expr: -5*em + out*(17.9293603727983 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 67.758537 and emission: 0.000000 and profit: 622.193001966937
# The profit expr: -5*em + out*(24.1425000710258 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 128.534217 and emission: 0.000000 and profit: 1819.11902224092
# The profit expr: -5*em + out*(21.6285179241102 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 104.892893 and emission: 98.467453 and profit: 1116.31550860704
# The profit expr: -5*em + out*(20.0715568775025 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 93.237519 and emission: 84.126956 and profit: 892.099893964247
# The profit expr: -5*em + out*(18.2684891924982 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 79.964526 and emission: 71.669396 and profit: 660.170357104161
# The profit expr: -5*em + out*(18.0126126074549 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 81.210416 and emission: 69.408354 and profit: 689.018318249674
# The profit expr: -5*em + out*(18.9307446688862 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 91.948048 and emission: 80.521755 and profit: 874.010094071664
# The profit expr: -5*em + out*(16.5987795072974 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 67.579936 and emission: 62.391398 and profit: 469.676111104375
# The profit expr: -5*em + out*(17.9388120482072 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 77.916433 and emission: 71.601109 and profit: 622.885366379811
# The profit expr: -5*em + out*(20.6957475206036 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 101.618654 and emission: 92.816527 and profit: 1054.64039102014
# The profit expr: -5*em + out*(17.3097358991608 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 65.472404 and emission: 0.000000 and profit: 580.916425888776
# The profit expr: -5*em + out*(23.6159171689342 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 126.143032 and emission: 0.000000 and profit: 1752.06467973625
# The profit expr: -5*em + out*(21.4909032828206 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 104.204820 and emission: 97.779379 and profit: 1101.92805519181
# The profit expr: -5*em + out*(20.3941731254756 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 94.850600 and emission: 85.740037 and profit: 922.440035476786
# The profit expr: -5*em + out*(18.905565700549 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 83.149908 and emission: 74.854779 and profit: 712.128543994255
# The profit expr: -5*em + out*(18.7116164791764 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 84.705435 and emission: 72.903374 and profit: 747.006229394384
# The profit expr: -5*em + out*(19.4358777933182 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 94.473714 and emission: 83.047420 and profit: 921.093997710683
# The profit expr: -5*em + out*(16.7464999454174 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 68.318538 and emission: 63.130001 and profit: 479.713602105201
# The profit expr: -5*em + out*(17.7062894991302 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 76.753820 and emission: 70.438497 and profit: 604.903205548634
# The profit expr: -5*em + out*(20.1927728062163 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 99.103780 and emission: 90.301654 and profit: 1004.16123667749
# The profit expr: -5*em + out*(16.82963524431 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.701051 and emission: 0.000000 and profit: 549.908295668091
# The profit expr: -5*em + out*(23.0738333714345 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 123.681459 and emission: 0.000000 and profit: 1684.35177540729
# The profit expr: -5*em + out*(21.1261695265511 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 102.381151 and emission: 95.955711 and profit: 1064.25361651035
# The profit expr: -5*em + out*(20.3731143713309 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 94.745306 and emission: 85.634743 and profit: 920.443708693221
# The profit expr: -5*em + out*(19.2135745774977 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 84.689952 and emission: 76.394823 and profit: 737.976627470335
# The profit expr: -5*em + out*(19.2151228535141 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 87.222967 and emission: 75.420906 and profit: 790.289752642485
# The profit expr: -5*em + out*(19.940197542704 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 96.995313 and emission: 85.569019 and profit: 969.374803495771
# The profit expr: -5*em + out*(17.0725200391676 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 69.948638 and emission: 64.760101 and profit: 502.252540924113
# The profit expr: -5*em + out*(17.7530382714667 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 76.987564 and emission: 70.672241 and profit: 608.496816047940
# The profit expr: -5*em + out*(19.9646598351953 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 97.963215 and emission: 89.161089 and profit: 981.684467803800
# The profit expr: -5*em + out*(16.5384434135239 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 62.626685 and emission: 0.000000 and profit: 531.515493282330
# The profit expr: -5*em + out*(22.6439207439168 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.729248 and emission: 0.000000 and profit: 1631.59919451193
# The profit expr: -5*em + out*(20.709111052614 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 100.295859 and emission: 93.870418 and profit: 1021.98953419973
# The profit expr: -5*em + out*(20.1540557572898 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 93.650013 and emission: 84.539450 and profit: 899.808899961421
# The profit expr: -5*em + out*(19.2580497089512 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 84.912328 and emission: 76.617199 and profit: 741.748169332187
# The profit expr: -5*em + out*(19.4891136064075 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 88.592921 and emission: 76.790859 and profit: 814.375716397906
# The profit expr: -5*em + out*(20.3293527938443 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 98.941089 and emission: 87.514795 and profit: 1007.49964330556
# The profit expr: -5*em + out*(17.4301077116124 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 71.736577 and emission: 66.548039 and profit: 527.584983995466
# The profit expr: -5*em + out*(17.9552064938575 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 77.998405 and emission: 71.683082 and profit: 624.163435054371
# The profit expr: -5*em + out*(19.9516874608798 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 97.898353 and emission: 89.096227 and profit: 980.414073014174
# The profit expr: -5*em + out*(16.4245206612251 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 62.206362 and emission: 0.000000 and profit: 524.404831120036
# The profit expr: -5*em + out*(22.3768092832516 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 120.516309 and emission: 0.000000 and profit: 1599.24591214627
# The profit expr: -5*em + out*(20.3547642449424 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 98.524125 and emission: 92.098684 and profit: 986.763920901568
# The profit expr: -5*em + out*(19.8673530464338 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 92.216499 and emission: 83.105936 and profit: 873.164683489206
# The profit expr: -5*em + out*(19.136935919251 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 84.306759 and emission: 76.011630 and profit: 731.500786856486
# The profit expr: -5*em + out*(19.565552088006 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 88.975113 and emission: 77.173052 and profit: 821.162231852396
# The profit expr: -5*em + out*(20.5621496602152 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 100.105073 and emission: 88.678780 and profit: 1030.66830472996
# The profit expr: -5*em + out*(17.7252999810218 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.212538 and emission: 68.024001 and profit: 548.978913010433
# The profit expr: -5*em + out*(18.2038867397575 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 79.241807 and emission: 72.926483 and profit: 643.714702366493
# The profit expr: -5*em + out*(20.0695413966709 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 98.487623 and emission: 89.685497 and profit: 991.986503128990
# The profit expr: -5*em + out*(16.44141530577 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 62.268696 and emission: 0.000000 and profit: 525.456312046646
# The profit expr: -5*em + out*(22.2661766810387 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 120.013933 and emission: 0.000000 and profit: 1585.94066885696
# The profit expr: -5*em + out*(20.1171959136287 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.336283 and emission: 90.910843 and profit: 963.498805727697
# The profit expr: -5*em + out*(19.605217525348 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.905822 and emission: 81.795259 and profit: 849.163250947050
# The profit expr: -5*em + out*(18.9453112638576 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 83.348636 and emission: 75.053507 and profit: 715.437333204364
# The profit expr: -5*em + out*(19.5079590011074 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 88.687148 and emission: 76.885086 and profit: 816.046172831362
# The profit expr: -5*em + out*(20.6497515499488 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 100.543083 and emission: 89.116789 and profit: 1039.45688355248
# The profit expr: -5*em + out*(17.916697060594 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 74.169523 and emission: 68.980986 and profit: 563.083161053094
# The profit expr: -5*em + out*(18.4239254024935 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.342000 and emission: 74.026676 and profit: 661.272006076668
# The profit expr: -5*em + out*(20.2384876959333 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 99.332354 and emission: 90.530228 and profit: 1008.69697967805
# The profit expr: -5*em + out*(16.532121812197 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 62.603361 and emission: 0.000000 and profit: 531.119666067708
# The profit expr: -5*em + out*(22.2731789300563 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 120.045729 and emission: 0.000000 and profit: 1586.78114762334
# The profit expr: -5*em + out*(20.0022343130488 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 96.761475 and emission: 90.336035 and profit: 952.341911232006
# The profit expr: -5*em + out*(19.4166689645155 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 89.963079 and emission: 80.852516 and profit: 832.111965477476
# The profit expr: -5*em + out*(18.755224655743 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 82.398203 and emission: 74.103074 and profit: 699.684206012720
# The profit expr: -5*em + out*(19.3841191535972 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 88.067949 and emission: 76.265887 and profit: 805.101510737289
# The profit expr: -5*em + out*(20.6316325710613 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 100.452488 and emission: 89.026194 and profit: 1037.63596630199
# The profit expr: -5*em + out*(18.0033361109353 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 74.602719 and emission: 69.414181 and profit: 569.527903926392
# The profit expr: -5*em + out*(18.5772642590324 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 81.108694 and emission: 74.793370 and profit: 673.650338501991
# The profit expr: -5*em + out*(20.3996302738348 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.138067 and emission: 91.335941 and profit: 1024.76856866709
# The profit expr: -5*em + out*(16.6461596838247 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.024109 and emission: 0.000000 and profit: 538.282810762197
# The profit expr: -5*em + out*(22.3483216884532 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 120.386949 and emission: 0.000000 and profit: 1595.81453494572
# The profit expr: -5*em + out*(19.9857743452539 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 96.679175 and emission: 90.253735 and profit: 950.749897791599
# The profit expr: -5*em + out*(19.3141647002034 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 89.450558 and emission: 80.339995 and profit: 822.916634061689
# The profit expr: -5*em + out*(18.6089292195346 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.666726 and emission: 73.371597 and profit: 687.683230870097
# The profit expr: -5*em + out*(19.2490515117376 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 87.392610 and emission: 75.590549 and profit: 793.251988766886
# The profit expr: -5*em + out*(20.5550392606876 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 100.069521 and emission: 88.643228 and profit: 1029.95664405836
# The profit expr: -5*em + out*(18.0083589809191 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 74.627833 and emission: 69.439296 and profit: 569.902686755045
# The profit expr: -5*em + out*(18.6564451222935 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 81.504599 and emission: 75.189275 and profit: 680.088268956545
# The profit expr: -5*em + out*(20.5197919944136 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.738876 and emission: 91.936750 and profit: 1036.83742823020
# The profit expr: -5*em + out*(16.7483153412855 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.401017 and emission: 0.000000 and profit: 544.740331734607
# The profit expr: -5*em + out*(22.4469084721874 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 120.834626 and emission: 0.000000 and profit: 1607.70516455591
# The profit expr: -5*em + out*(20.0313634122944 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 96.907121 and emission: 90.481680 and profit: 955.162607109395
# The profit expr: -5*em + out*(19.2857071015674 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 89.308270 and emission: 80.197707 and profit: 820.373110581327
# The profit expr: -5*em + out*(18.5215527021141 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.229843 and emission: 72.934714 and profit: 680.566563431177
# The profit expr: -5*em + out*(19.1378294320985 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.836500 and emission: 75.034438 and profit: 783.562926772238
# The profit expr: -5*em + out*(20.461131565681 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.599983 and emission: 88.173689 and profit: 1020.58139260846
# The profit expr: -5*em + out*(17.9639165684074 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 74.405621 and emission: 69.217084 and profit: 566.590983641623
# The profit expr: -5*em + out*(18.6738143476683 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 81.591445 and emission: 75.276121 and profit: 681.504694923774
# The profit expr: -5*em + out*(20.5885574673903 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 101.082703 and emission: 92.280577 and profit: 1043.77660640632
# The profit expr: -5*em + out*(16.8203888774025 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.666936 and emission: 0.000000 and profit: 549.319450098488
# The profit expr: -5*em + out*(22.5371578784743 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.244444 and emission: 0.000000 and profit: 1618.62891071807
# The profit expr: -5*em + out*(20.1034255779464 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.267432 and emission: 90.841991 and profit: 962.158926488302
# The profit expr: -5*em + out*(19.3075093850727 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 89.417281 and emission: 80.306718 and profit: 822.321423144894
# The profit expr: -5*em + out*(18.4887655851548 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.065908 and emission: 72.770778 and profit: 677.905958552944
# The profit expr: -5*em + out*(19.0658248337995 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.476477 and emission: 74.674415 and profit: 777.323261128410
# The profit expr: -5*em + out*(20.3781754190301 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.185202 and emission: 87.758908 and profit: 1012.33616613056
# The profit expr: -5*em + out*(17.9002172888275 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 74.087124 and emission: 68.898587 and profit: 561.861543194703
# The profit expr: -5*em + out*(18.6506493205658 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 81.475620 and emission: 75.160296 and profit: 679.615968441422
# The profit expr: -5*em + out*(20.6113576903274 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 101.196704 and emission: 92.394578 and profit: 1046.08261420192
# The profit expr: -5*em + out*(16.8583808514972 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.807109 and emission: 0.000000 and profit: 551.740945408932
# The profit expr: -5*em + out*(22.602114313146 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.539407 and emission: 0.000000 and profit: 1626.51409740467
# The profit expr: -5*em + out*(20.174916724829 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.624887 and emission: 91.199447 and profit: 969.125464187628
# The profit expr: -5*em + out*(19.3541561002684 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 89.650515 and emission: 80.539952 and profit: 826.497885379317
# The profit expr: -5*em + out*(18.495695384272 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.100556 and emission: 72.805427 and profit: 678.467849062467
# The profit expr: -5*em + out*(19.0332874342073 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.313790 and emission: 74.511728 and profit: 774.512188147007
# The profit expr: -5*em + out*(20.3204286459061 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 98.896468 and emission: 87.470175 and profit: 1006.61687749131
# The profit expr: -5*em + out*(17.8394942624738 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.783509 and emission: 68.594972 and profit: 557.371967001218
# The profit expr: -5*em + out*(18.6087052938374 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 81.265899 and emission: 74.950576 and profit: 676.202951128798
# The profit expr: -5*em + out*(20.6017857884318 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 101.148845 and emission: 92.346719 and profit: 1045.11419832843
# The profit expr: -5*em + out*(16.8676122141275 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.841169 and emission: 0.000000 and profit: 552.330129179759
# The profit expr: -5*em + out*(22.6374360926907 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.699802 and emission: 0.000000 and profit: 1630.80991826800
# The profit expr: -5*em + out*(20.2299446460714 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.900027 and emission: 91.474586 and profit: 974.505128979228
# ...
# Firm dummy_firm3 has output: 98.985225 and emission: 87.558932 and profit: 1008.37321650808
# The profit expr: -5*em + out*(17.7849743816698 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.510910 and emission: 68.322373 and profit: 553.356729913319
# The profit expr: -5*em + out*(18.5062171474635 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.753459 and emission: 74.438135 and profit: 667.900419279790
# The profit expr: -5*em + out*(20.4909856794045 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.594844 and emission: 91.792718 and profit: 1033.93758694598
# The profit expr: -5*em + out*(16.7877981386859 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.546691 and emission: 0.000000 and profit: 547.246457059400
# The profit expr: -5*em + out*(22.5823217396934 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.449530 and emission: 0.000000 and profit: 1624.10940920352
# The profit expr: -5*em + out*(20.2365539988312 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.933074 and emission: 91.507633 and profit: 975.152294001309
# The profit expr: -5*em + out*(19.4714787117688 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.237128 and emission: 81.126565 and profit: 837.050329369584
# The profit expr: -5*em + out*(18.6232468244941 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.738314 and emission: 73.443185 and profit: 688.853015271141
# The profit expr: -5*em + out*(19.1250825197078 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.772765 and emission: 74.970704 and profit: 782.456435724024
# The profit expr: -5*em + out*(20.3463285044663 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.025968 and emission: 87.599674 and profit: 1009.17995903775
# The profit expr: -5*em + out*(17.7948227381738 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.560152 and emission: 68.371615 and profit: 554.080934036056
# The profit expr: -5*em + out*(18.5141534451364 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.793140 and emission: 74.477816 and profit: 668.541460228450
# The profit expr: -5*em + out*(20.4943238586198 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.611535 and emission: 91.809409 and profit: 1034.27341842318
# The profit expr: -5*em + out*(16.7878394327031 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.546843 and emission: 0.000000 and profit: 547.249081160699
# The profit expr: -5*em + out*(22.5781081438036 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.430397 and emission: 0.000000 and profit: 1623.59771027203
# The profit expr: -5*em + out*(20.2283758394185 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.892183 and emission: 91.466742 and profit: 974.351548918544
# The profit expr: -5*em + out*(19.4628703209122 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.194086 and emission: 81.083523 and profit: 836.273718165397
# The profit expr: -5*em + out*(18.6172931142634 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.708545 and emission: 73.413416 and profit: 688.366457653305
# The profit expr: -5*em + out*(19.1237151421597 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.765929 and emission: 74.963867 and profit: 782.337789267095
# The profit expr: -5*em + out*(20.3497190426045 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.042920 and emission: 87.616627 and profit: 1009.51573909674
# The profit expr: -5*em + out*(17.8014421854971 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.593249 and emission: 68.404712 and profit: 554.567971127777
# The profit expr: -5*em + out*(18.5214313176345 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.829530 and emission: 74.514206 and profit: 669.129594820257
# The profit expr: -5*em + out*(20.4996318844766 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.638075 and emission: 91.835949 and profit: 1034.80753749162
# The profit expr: -5*em + out*(16.7905086812491 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.556692 and emission: 0.000000 and profit: 547.418716623664
# The profit expr: -5*em + out*(22.577879189397 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.429357 and emission: 0.000000 and profit: 1623.56990836662
# The profit expr: -5*em + out*(20.2241617722809 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.871113 and emission: 91.445672 and profit: 973.939069083444
# The profit expr: -5*em + out*(19.456459091915 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.162030 and emission: 81.051467 and profit: 835.695565987013
# The profit expr: -5*em + out*(18.6111106446501 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.677633 and emission: 73.382504 and profit: 687.861392613116
# The profit expr: -5*em + out*(19.1199402185765 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.747054 and emission: 74.944992 and profit: 782.010290142363
# The profit expr: -5*em + out*(20.3495268498789 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.041959 and emission: 87.615666 and profit: 1009.49670386030
# The profit expr: -5*em + out*(17.8046558127951 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.609317 and emission: 68.420780 and profit: 554.804498219886
# The profit expr: -5*em + out*(18.5266770675326 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.855758 and emission: 74.540435 and profit: 669.553675111561
# The profit expr: -5*em + out*(20.504908772354 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.664460 and emission: 91.862333 and profit: 1035.33866294546
# The profit expr: -5*em + out*(16.7941319567151 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.570060 and emission: 0.000000 and profit: 547.649024243627
# The profit expr: -5*em + out*(22.5800616737406 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.439268 and emission: 0.000000 and profit: 1623.83493685210
# The profit expr: -5*em + out*(20.2232461685528 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.866535 and emission: 91.441094 and profit: 973.849460023729
# The profit expr: -5*em + out*(19.4527956755516 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.143713 and emission: 81.033150 and profit: 835.365298483896
# The profit expr: -5*em + out*(18.6061877016598 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.653018 and emission: 73.357889 and profit: 687.459358871690
# The profit expr: -5*em + out*(19.1155912852895 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.725309 and emission: 74.923248 and profit: 781.633080275078
# The profit expr: -5*em + out*(20.3472562868736 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.030606 and emission: 87.604313 and profit: 1009.27183574024
# The profit expr: -5*em + out*(17.8051273449419 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.611675 and emission: 68.423138 and profit: 554.839207935029
# The profit expr: -5*em + out*(18.5295357085551 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.870052 and emission: 74.554728 and profit: 669.784833128801
# The profit expr: -5*em + out*(20.5089765368041 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.684799 and emission: 91.882672 and profit: 1035.74818362327
# The profit expr: -5*em + out*(16.7975026630873 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.582496 and emission: 0.000000 and profit: 547.863321209266
# The profit expr: -5*em + out*(22.5831797969971 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.453427 and emission: 0.000000 and profit: 1624.21362153183
# The profit expr: -5*em + out*(20.2244905668014 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.872757 and emission: 91.447316 and profit: 973.971248839237
# The profit expr: -5*em + out*(19.451586166496 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.137665 and emission: 81.027102 and profit: 835.256272504562
# The profit expr: -5*em + out*(18.6031214756387 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.637687 and emission: 73.342558 and profit: 687.209015767295
# The profit expr: -5*em + out*(19.1118837056358 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.706771 and emission: 74.904710 and profit: 781.311573648399
# The profit expr: -5*em + out*(20.3442672155436 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.015661 and emission: 87.589367 and profit: 1008.97584853007
# The profit expr: -5*em + out*(17.8038685753508 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.605381 and emission: 68.416844 and profit: 554.746551758625
# The profit expr: -5*em + out*(18.5303356442706 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.874051 and emission: 74.558727 and profit: 669.849525571084
# The profit expr: -5*em + out*(20.5114103868867 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.696968 and emission: 91.894842 and profit: 1035.99325013783
# The profit expr: -5*em + out*(16.7999632257471 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.591575 and emission: 0.000000 and profit: 548.019781094333
# The profit expr: -5*em + out*(22.586148446891 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.466907 and emission: 0.000000 and profit: 1624.57419424397
# The profit expr: -5*em + out*(20.2267333677326 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.883971 and emission: 91.458530 and profit: 974.190770524131
# The profit expr: -5*em + out*(19.4521028124334 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.140248 and emission: 81.029685 and profit: 835.302842430288
# The profit expr: -5*em + out*(18.6018466855964 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.631313 and emission: 73.336184 and profit: 687.104948919609
# The profit expr: -5*em + out*(19.1093925207871 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.694315 and emission: 74.892254 and profit: 781.095586568322
# The profit expr: -5*em + out*(20.3415270874541 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 99.001960 and emission: 87.575667 and profit: 1008.70455170656
# The profit expr: -5*em + out*(17.8018691265097 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.595384 and emission: 68.406846 and profit: 554.599391559681
# The profit expr: -5*em + out*(18.529735887708 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.871052 and emission: 74.555729 and profit: 669.801021727391
# The profit expr: -5*em + out*(20.5123274336467 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.701553 and emission: 91.899427 and profit: 1036.08559606841
# The profit expr: -5*em + out*(16.8013295850369 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.596616 and emission: 0.000000 and profit: 548.106673477150
# The profit expr: -5*em + out*(22.5883587297237 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.476944 and emission: 0.000000 and profit: 1624.84268155605
# The profit expr: -5*em + out*(20.2290613733824 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.895611 and emission: 91.470170 and profit: 974.418658509612
# The profit expr: -5*em + out*(19.453525138227 - 0.1*out) + 3.5759468318621*out - 0.274406751963662*(-em + out)**2
# Firm dummy_firm0 has output: 90.147360 and emission: 81.036797 and profit: 835.431056287901
# The profit expr: -5*em + out*(18.6019204534742 - 0.1*out) + 2.72441591498448*out - 0.301381688035822*(-em + out)**2
# Firm dummy_firm1 has output: 81.631682 and emission: 73.336553 and profit: 687.110970701943
# The profit expr: -5*em + out*(19.1081838123017 - 0.1*out) + 3.22947056533328*out - 0.211827399669452*(-em + out)**2
# Firm dummy_firm2 has output: 86.688272 and emission: 74.886210 and profit: 780.990802066063
# The profit expr: -5*em + out*(20.3395526691673 - 0.1*out) + 4.4588650039104*out - 0.218793605631346*(-em + out)**2
# Firm dummy_firm3 has output: 98.992088 and emission: 87.565795 and profit: 1008.50909017122
# The profit expr: -5*em + out*(17.7998821929471 - 0.1*out) + 1.91720759412889*out - 0.481831380250515*(-em + out)**2
# Firm dummy_firm4 has output: 73.585449 and emission: 68.396912 and profit: 554.453172291705
# The profit expr: -5*em + out*(18.5284425426453 - 0.1*out) + 2.64447459876452*out - 0.395862519041332*(-em + out)**2
# Firm dummy_firm5 has output: 80.864586 and emission: 74.549262 and profit: 669.696431732865
# The profit expr: -5*em + out*(20.5121392844955 - 0.1*out) + 4.62798319146331*out - 0.284022280546966*(-em + out)**2
# Firm dummy_firm6 has output: 100.700612 and emission: 91.898486 and profit: 1036.06664924516
# The profit expr: -5*em + out*(16.8017396350054 - 0.1*out) + 0.435646498507704*out - 0.0355180290989435*(-em + out)**2
# Firm dummy_firm7 has output: 63.598129 and emission: 0.000000 and profit: 548.132751577666
# The profit expr: -5*em + out*(22.5896211675187 - 0.1*out) + 4.16309922773969*out - 0.0101091987201629*(-em + out)**2
# Firm dummy_firm8 has output: 121.482677 and emission: 0.000000 and profit: 1624.99604226008
# The profit expr: -5*em + out*(20.2309145477314 - 0.1*out) + 4.3500607412341*out - 0.389078375474925*(-em + out)**2
# Firm dummy_firm9 has output: 97.904876 and emission: 91.479436 and profit: 974.600084729644

# %%
# Robustsness check for the initial value of the output
def robustness_check():
    # Select random seed
    np.random.seed(0)
    market, sector, firms = generate_dataframes(100)
    optimize_them_all(firms, market, sector, print_output=False, print_diff=True)
    firms_df = pd.concat(firms)
    firms_df.to_csv('firms100.csv', index=False)

    # Select random seed
    for i in tqdm.tqdm(range(10)):
        np.random.seed(i)
        for firm in firms:
            firm["actual_output"] = np.random.randint(100, 20000)
        optimize_them_all(firms, market, sector, print_output=False, print_diff=True)
        # Compare to firms100.csv and print the diviation on emission, output and profit
        firms_df = pd.concat(firms)
        firms100 = pd.read_csv('firms100.csv')
        print("Seed: {}".format(i))
        # Calculate the max and mean diviation of profit, emissions and output, between the two runs
        max_output_diff = 0
        mean_output_diff = 0
        max_emission_diff = 0
        mean_emission_diff = 0
        max_profit_diff = 0
        mean_profit_diff = 0
        for i in range(len(firms)):
            max_output_diff = max(max_output_diff, abs(firms[i]['actual_output'][0] - firms100['actual_output'][i]))
            mean_output_diff += abs(firms[i]['actual_output'][0] - firms100['actual_output'][i])
            max_emission_diff = max(max_emission_diff, abs(firms[i]['emission'][0] - firms100['emission'][i]))
            mean_emission_diff += abs(firms[i]['emission'][0] - firms100['emission'][i])
            max_profit_diff = max(max_profit_diff, abs(firms[i]['profit'][0] - firms100['profit'][i]))
            mean_profit_diff += abs(firms[i]['profit'][0] - firms100['profit'][i])
        mean_output_diff /= len(firms)
        mean_emission_diff /= len(firms)
        mean_profit_diff /= len(firms)
        print("Max output diff: {:5f}".format(max_output_diff), end = " ")
        print("Mean output diff: {:5f}".format(mean_output_diff), end = " ")
        print("Max emission diff: {:5f}".format(max_emission_diff), end = " ")
        print("Mean emission diff: {:5f}".format(mean_emission_diff), end = " ")
        print("Max profit diff: {:5f}".format(max_profit_diff), end = " ")
        print("Mean profit diff: {:5f}".format(mean_profit_diff), end = " ")
        print("")
#robustness_check()
