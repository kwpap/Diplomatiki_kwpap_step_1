# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
from funkwpap import *
import sympy as sp, pandas as pd, numpy as np, tqdm, time, sys, matplotlib.pyplot as plt, tqdm
from statistics import mean
from scipy.optimize import fsolve
import gurobipy as gb

# %%
import sympy as sp

# Define symbolic variable
x = sp.symbols('x')

# Create a Regulator with an emission cap
RegulatorETS = Regulator("ETS", permit_price=20.0, emission_cap=1000000)

# Define Countries with updated names and attributes
country1 = Country('Atlantis', size=50, regulator=RegulatorETS, GDP_per_capita=400, population=100000000, industry_percentage=30)


# Define Sectors with demand functions
sector1 = Sector('Steel', price_demand_function=200 - 0.1*x, free_emission_multiplier=0.8, regulator=RegulatorETS)
sector2 = Sector('Cement', price_demand_function=150 - 0.05*x, free_emission_multiplier=0.85, regulator=RegulatorETS)


# Create Firms with updated definitions (production_cost_function=0, abatement_cost_function as previous production_cost_function)
# Firms in Sector 1: Steel
firm_S1_F1 = Firm('S1_F1', sector1, country1, x*0, 2*x + 3*x**2 + x**3, 10000, 5000, 0, RegulatorETS)
# firm_S1_F2 = Firm('S1_F2', sector1, country1, x*0, 3*x + 2*x**2 + 2*x**3, 12000, 6000, 0, RegulatorETS)


# # Firms in Sector 2: Cement
# firm_S2_F1 = Firm('S2_F1', sector2, country1, x*0, x + 2*x**2 + 3*x**3, 9000, 4500, 0, RegulatorETS)
firm_S2_F2 = Firm('S2_F2', sector2, country1, x*0, 2*x + x**2 + 2*x**3, 9500, 4750, 0, RegulatorETS)

# %%
RegulatorETS.BAU_calculator(precision = 0.01, print_diff = True)
#print(RegulatorETS.BAU_emissions)
# 17638.87773  3750 for 2
RegulatorETS.emission_cap = RegulatorETS.BAU_emissions*0.8
# Optimal solution found for 2 sectors.
# Firm S1_F1 has output 451.62827788960453 and emission 446.7349764049005
# Firm S1_F2 has output 451.6282778896044 and emission 447.8616178523027
# Firm S1_F3 has output 451.6282778896045 and emission 448.41767394370135
# Firm S2_F1 has output 556.5131115584181 and emission 553.3583289997191
# Firm S2_F2 has output 556.513111558418 and emission 552.5696348002654
# Firm S2_F3 has output 556.5131115584182 and emission 551.0577679991109
# Permit price: 103.19300716884365
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-14
# Max diff: 0.00, permit price = 20.0, cap = 1000000, second_stage = False, a = 1.00.00

# %%
RegulatorETS.optimization_with_positive_constraints_ab(print_output= True, gurobi_print=False)
RegulatorETS.equilibrium_tester(full_output=True)
# Out:
# Optimal solution found
# Firm S1_F1 has output 805.0355980200349 and emission 797.953428303229
# Firm S2_F2 has output 1207.553397030052 and emission 1202.046571696771
# Permit price: 194.96440197996523
# Firm       | FOC 1        | FOC 2         | SOC 1         | SOC 2        | Hessian      | Status
# -------------------------------------------------------------------------------------
# Worst      |  +1.94e-7 ✔️ |  +1.94e-7 ✔️ |  -48.4930 ✔️ |  -48.6930 ✔️ |   +6.8082 ✔️ | 5/5
# S1_F1      |  -1.38e-8 ✔️ |  +1.38e-8 ✔️ |  -48.4930 ✔️ |  -48.6930 ✔️ |   +9.6986 ✔️ | 5/5
# S2_F2      |  -1.94e-7 ✔️ |  +1.94e-7 ✔️ |  -68.0819 ✔️ |  -68.1819 ✔️ |   +6.8082 ✔️ | 5/5
# (True, 1.94192807612126e-7)

# %%
coeff = RegulatorETS.exp7_find_coefficient_for_free_allocation(print_output=True, percentage=0.4)
# Out:
# Lower bound: 0, Upper bound: 1.0, Current bound: 0.5, Total free allocation: 1670.448865891572
# Lower bound: 0, Upper bound: 0.5, Current bound: 0.25, Total free allocation: 831.8780917896597
# Lower bound: 0.25, Upper bound: 0.5, Current bound: 0.375, Total free allocation: 415.68448331503976
# Lower bound: 0.375, Upper bound: 0.5, Current bound: 0.4375, Total free allocation: 623.6949946103666
# Lower bound: 0.4375, Upper bound: 0.5, Current bound: 0.46875, Total free allocation: 727.7607499767088
# Lower bound: 0.46875, Upper bound: 0.5, Current bound: 0.484375, Total free allocation: 779.8123086789137
# Lower bound: 0.46875, Upper bound: 0.484375, Current bound: 0.4765625, Total free allocation: 805.8433281591517
# Lower bound: 0.4765625, Upper bound: 0.484375, Current bound: 0.48046875, Total free allocation: 792.8273627085894

# %%
for sector in RegulatorETS.sector_registry.values():
    sector.free_emission_multiplier *= coeff

# %%
RegulatorETS.optimization_with_positive_constraints_ab(print_output= True, gurobi_print=False)
for firm in RegulatorETS.firm_registry.values():
    firm.calculate_profit_components()
print(sum([firm.free_permits for firm in RegulatorETS.firm_registry.values()]))
print(RegulatorETS.emission_cap*0.4)
# Out:
# Optimal solution found
# Firm S1_F1 has output 830.9777295967303 and emission 827.6606785818444
# Firm S2_F2 has output 1175.1469181145278 and emission 1172.3393214181556
# Permit price: 54.91078835436175
# 799.3352300046569
# 800.0

# %%
consumer_surplus = 0
for sector in RegulatorETS.sector_registry.values():
    consumer_surplus += sector.get_consumer_surplus()
print(consumer_surplus)
# 721857.091272771
# Out:
# 69050.4563331386

# %%
for sector in RegulatorETS.sector_registry.values():
    print(f"{sector.name} has a free emission multiplier {sector.free_emission_multiplier}")
# Out:
# Steel has a free emission multiplier 0.384375
# Cement has a free emission multiplier 0.4083984375

# %%
for firm in RegulatorETS.firm_registry.values():
    firm.calculate_profit_components()

# %%
# =======================
# 1. Configuration Variables
# =======================
RUN_NAME = 'run_ULM'  # Unique identifier for the current run
BASE_PATH = 'C:/Users/Kostas/Documents/GitHub/Diplomatiki_kwpap_step_1/2024 Project v2/data/exp7'  # Fixed base path for data storage

# =======================
# 5. Data Saving
# =======================

def save_data(regulator, run_name, base_path):
    """
    Saves the data from the regulator object into CSV files.

    Parameters:
    - regulator (Regulator): The regulator instance containing all data.
    - run_name (str): Unique identifier for the current run.
    - base_path (str): Fixed base directory for data storage.
    """
    # Define run-specific paths
    run_path = os.path.join(base_path, run_name)
    data_dir = os.path.join(run_path, 'data')
    summaries_dir = os.path.join(run_path, 'summaries')

    # Create directories if they don't exist
    os.makedirs(data_dir, exist_ok=True)
    os.makedirs(summaries_dir, exist_ok=True)

    # 1. Extract Regulator Data
    regulator_data = {
        'id': [regulator.id],
        'name': [regulator.name],
        'permit_price': [regulator.permit_price],
        'emission_cap': [regulator.emission_cap],
        'BAU_emissions': [regulator.BAU_emissions],
        'BAU_profit': [regulator.BAU_profit]
    }

    df_regulator = pd.DataFrame(regulator_data)

    # Save Regulator DataFrame to CSV
    regulator_csv = os.path.join(data_dir, f'{run_name}_regulator.csv')
    df_regulator.to_csv(regulator_csv, index=False)
    print(f"Regulator data saved to {regulator_csv}.")

    # 2. Extract Countries Data
    countries = regulator.country_registry.values()
    country_list = []
    for country in countries:
        country_list.append({
            'id': country.id,
            'name': country.name,
            'size': country.size,
            'GDP_per_capita': country.GDP_per_capita,
            'population': country.population,
            'industry_percentage': country.industry_percentage,
            'GDP': country.GDP
        })

    df_countries = pd.DataFrame(country_list)

    # Save Countries DataFrame to CSV
    countries_csv = os.path.join(data_dir, f'{run_name}_countries.csv')
    df_countries.to_csv(countries_csv, index=False)
    print(f"Countries data saved to {countries_csv}.")

    # 3. Extract Sectors Data
    sectors = regulator.sector_registry.values()
    sector_list = []
    for sector in sectors:
        sector_list.append({
            'id': sector.id,
            'name': sector.name,
            'price_demand_function': str(sector.price_demand_function),
            'free_emission_multiplier': sector.free_emission_multiplier,
            'consumer_surplus': sector.consumer_surplus  # Include consumer_surplus
        })

    df_sectors = pd.DataFrame(sector_list)

    # Save Sectors DataFrame to CSV
    sectors_csv = os.path.join(data_dir, f'{run_name}_sectors.csv')
    df_sectors.to_csv(sectors_csv, index=False)
    print(f"Sectors data saved to {sectors_csv}.")

    # 4. Extract Firms Data
    firm_list = []
    for sector in sectors:
        for firm in sector.firms:
            firm_list.append({
                'id': firm.id,
                'name': firm.name,
                'sector_id': firm.sector.id,
                'country_id': firm.country.id,
                'production_cost_function': str(firm.production_cost_function),
                'abatement_cost_function': str(firm.abatement_cost_function),
                'actual_output': firm.actual_output,
                'emission': firm.emission,
                'profit': firm.profit,
                'BAU_output': firm.BAU_output,
                'BAU_emission': firm.BAU_emission,
                'BAU_profit': firm.BAU_profit,
                'exp7_free_allocation': firm.exp7_free_allocation,
                'abatement': firm.abatement,
                'permits_costs': firm.permits_costs,
                'sales': firm.sales,
                'permits_used': firm.permits_used,
                'free_permits': firm.free_permits,
                'permits_bought': firm.permits_bought
            })

    df_firms = pd.DataFrame(firm_list)

    # Save Firms DataFrame to CSV
    firms_csv = os.path.join(data_dir, f'{run_name}_firms.csv')
    df_firms.to_csv(firms_csv, index=False)
    print(f"Firms data saved to {firms_csv}.")

    # 5. Save Summary Statistics
    # Regulator Summary
    regulator_summary_csv = os.path.join(summaries_dir, f'{run_name}_summary_regulator.csv')
    df_regulator.describe().to_csv(regulator_summary_csv)
    print(f"Regulator summary saved to {regulator_summary_csv}.")

    # Sectors Summary
    sectors_summary_csv = os.path.join(summaries_dir, f'{run_name}_summary_sectors.csv')
    df_sectors.describe(include='all').to_csv(sectors_summary_csv)
    print(f"Sectors summary saved to {sectors_summary_csv}.")

    # Countries Summary
    countries_summary_csv = os.path.join(summaries_dir, f'{run_name}_summary_countries.csv')
    df_countries.describe().to_csv(countries_summary_csv)
    print(f"Countries summary saved to {countries_summary_csv}.")

    # Firms Summary
    firms_summary_csv = os.path.join(summaries_dir, f'{run_name}_summary_firms.csv')
    df_firms.describe(include='all').to_csv(firms_summary_csv)
    print(f"Firms summary saved to {firms_summary_csv}.")

    print("\nAll data and summaries have been saved successfully.")

# =======================
# 6. Execute Data Saving
# =======================
save_data(RegulatorETS, RUN_NAME, BASE_PATH)
# Out:
# Regulator data saved to C:/Users/Kostas/Documents/GitHub/Diplomatiki_kwpap_step_1/2024 Project v2/data/exp7\run_ULM\data\run_ULM_regulator.csv.
# Countries data saved to C:/Users/Kostas/Documents/GitHub/Diplomatiki_kwpap_step_1/2024 Project v2/data/exp7\run_ULM\data\run_ULM_countries.csv.
# Sectors data saved to C:/Users/Kostas/Documents/GitHub/Diplomatiki_kwpap_step_1/2024 Project v2/data/exp7\run_ULM\data\run_ULM_sectors.csv.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 145
#     140     print("\nAll data and summaries have been saved successfully.")
#     142 # =======================
#     143 # 6. Execute Data Saving
#     144 # =======================
# --> 145 save_data(RegulatorETS, RUN_NAME, BASE_PATH)
#
# Cell In[11], line 116, in save_data(regulator, run_name, base_path)
#     114 # Save Firms DataFrame to CSV
#     115 firms_csv = os.path.join(data_dir, f'{run_name}_firms.csv')
# --> 116 df_firms.to_csv(firms_csv, index=False)
#     117 print(f"Firms data saved to {firms_csv}.")
#     119 # 5. Save Summary Statistics
#     120 # Regulator Summary
#
# File c:\Users\Kostas\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Kostas\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\Kostas\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Kostas\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\Kostas\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/Kostas/Documents/GitHub/Diplomatiki_kwpap_step_1/2024 Project v2/data/exp7\\run_ULM\\data\\run_ULM_firms.csv'

# %%
import optuna

# Define the objective function for optimization
def objective(trial):
    # Define possible multiplier values from 0 to 1 with 0.05 increments
    multiplier_values = [i * 0.05 for i in range(21)]
    
    # Assign a multiplier to each sector using sector names as keys
    multipliers = {}
    for sector in RegulatorETS.sector_registry.values():
        multipliers[sector.name] = trial.suggest_categorical(
            f"multiplier_{sector.name}", multiplier_values
        )
    
    try:
        # Set the free_emission_multiplier for each sector
        for sector in RegulatorETS.sector_registry.values():
            sector.free_emission_multiplier = multipliers[sector.name]
        
        # Find the scaling coefficient to maintain the emission cap percentage
        coeff = RegulatorETS.exp7_find_coefficient_for_free_allocation(
            print_output=False, percentage=0.4
        )
        
        # Check if coefficient was found
        if coeff is None:
            raise ValueError("Scaling coefficient not found.")
        
        # Scale the free_emission_multiplier for each sector
        for sector in RegulatorETS.sector_registry.values():
            sector.free_emission_multiplier *= coeff
        
        # Run the economic simulation with the updated multipliers
        RegulatorETS.optimization_with_positive_constraints_ab(
            print_output=False, gurobi_print=False
        )
        if (any (sector.free_emission_multiplier > 1 for sector in RegulatorETS.sector_registry.values())):
            return float('inf')  # Penalize invalid configurations
        
        # Calculate the total consumer surplus
        consumer_surplus = sum(
            sector.get_consumer_surplus() for sector in RegulatorETS.sector_registry.values()
        )
        
        # Since Optuna minimizes the objective, return the negative consumer surplus
        return -consumer_surplus
    
    except KeyError as e:
        print(f"KeyError encountered: {e}")
        return float('inf')  # Penalize invalid configurations
    except Exception as e:
        print(f"An error occurred: {e}")
        return float('inf')  # Penalize invalid configurations

# Create an Optuna study to maximize consumer surplus
study = optuna.create_study(direction='minimize')

# Optimize the objective function
study.optimize(objective, n_trials=100, show_progress_bar=True)

# Retrieve the best multipliers found
best_multipliers = {
    sector_name.replace("multiplier_", ""): value
    for sector_name, value in study.best_params.items()
}

# Display the optimal free_emission_multipliers for each sector
print("Optimal free_emission_multipliers:")
for sector, multiplier in best_multipliers.items():
    print(f"{sector}: {multiplier}")

# Optionally, set the best multipliers and calculate the final consumer surplus
for sector in RegulatorETS.sector_registry.values():
    sector.free_emission_multiplier = best_multipliers[sector.name]
    
# Apply the scaling coefficient
try:
    coeff = RegulatorETS.exp7_find_coefficient_for_free_allocation(
        print_output=False, percentage=0.4
    )
    if coeff is None:
        raise ValueError("Scaling coefficient not found.")
    for sector in RegulatorETS.sector_registry.values():
        sector.free_emission_multiplier *= coeff
    
    # Run the optimization with the best multipliers
    RegulatorETS.optimization_with_positive_constraints_ab(
        print_output=True, gurobi_print=False
    )
    
    # Calculate and print the maximum consumer surplus
    consumer_surplus = sum(
        sector.get_consumer_surplus() for sector in RegulatorETS.sector_registry.values()
    )
    print(f"Maximum Consumer Surplus: {consumer_surplus}")
    
except Exception as e:
    print(f"An error occurred during the final simulation: {e}")

# old run 1,0,0,1,0.9,0
# Out:
# [I 2024-11-15 11:42:19,098] A new study created in memory with name: no-name-a8d82b18-2001-4f0c-ab61-9b8c5bc21e53
#   0%|          | 0/100 [00:00<?, ?it/s]
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:42:45,889] Trial 0 finished with value: -682872.1484526532 and parameters: {'multiplier_Steel': 0.45, 'multiplier_Cement': 0.7000000000000001, 'multiplier_Paper': 0.75, 'multiplier_Chemicals': 0.0, 'multiplier_Automotive': 0.5, 'multiplier_Textiles': 0.8}. Best is trial 0 with value: -682872.1484526532.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:43:12,057] Trial 1 finished with value: inf and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.2, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.4, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.0}. Best is trial 0 with value: -682872.1484526532.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:43:39,439] Trial 2 finished with value: -678411.1382633972 and parameters: {'multiplier_Steel': 0.0, 'multiplier_Cement': 0.8, 'multiplier_Paper': 0.65, 'multiplier_Chemicals': 0.15000000000000002, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.9}. Best is trial 0 with value: -682872.1484526532.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:44:05,306] Trial 3 finished with value: -744069.1754942825 and parameters: {'multiplier_Steel': 0.75, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:44:30,332] Trial 4 finished with value: -735124.8646985106 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.35000000000000003, 'multiplier_Chemicals': 1.0, 'multiplier_Automotive': 0.8, 'multiplier_Textiles': 0.30000000000000004}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:44:55,592] Trial 5 finished with value: -706890.4723249451 and parameters: {'multiplier_Steel': 0.9500000000000001, 'multiplier_Cement': 0.8, 'multiplier_Paper': 0.8, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.4, 'multiplier_Textiles': 0.7000000000000001}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:45:20,590] Trial 6 finished with value: -701769.5267237858 and parameters: {'multiplier_Steel': 0.7000000000000001, 'multiplier_Cement': 0.35000000000000003, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.75, 'multiplier_Automotive': 0.8500000000000001, 'multiplier_Textiles': 0.9500000000000001}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:45:45,266] Trial 7 finished with value: inf and parameters: {'multiplier_Steel': 0.65, 'multiplier_Cement': 0.6000000000000001, 'multiplier_Paper': 0.35000000000000003, 'multiplier_Chemicals': 0.05, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.0}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:46:10,178] Trial 8 finished with value: -702977.9947944593 and parameters: {'multiplier_Steel': 0.75, 'multiplier_Cement': 0.2, 'multiplier_Paper': 0.15000000000000002, 'multiplier_Chemicals': 0.55, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.8}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:46:35,575] Trial 9 finished with value: -675696.7204242856 and parameters: {'multiplier_Steel': 0.25, 'multiplier_Cement': 0.55, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.5, 'multiplier_Automotive': 0.15000000000000002, 'multiplier_Textiles': 0.9500000000000001}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:47:00,994] Trial 10 finished with value: -735387.3100973648 and parameters: {'multiplier_Steel': 0.15000000000000002, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.65, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:47:25,058] Trial 11 finished with value: -735387.3100973648 and parameters: {'multiplier_Steel': 0.15000000000000002, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.65, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:47:49,443] Trial 12 finished with value: -713453.6130033415 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.0, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.65}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:48:13,678] Trial 13 finished with value: -735387.3100973648 and parameters: {'multiplier_Steel': 0.15000000000000002, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.65, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:48:38,157] Trial 14 finished with value: inf and parameters: {'multiplier_Steel': 1.0, 'multiplier_Cement': 0.0, 'multiplier_Paper': 0.2, 'multiplier_Chemicals': 0.65, 'multiplier_Automotive': 0.35000000000000003, 'multiplier_Textiles': 0.4}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:49:02,300] Trial 15 finished with value: -729350.9529519631 and parameters: {'multiplier_Steel': 0.35000000000000003, 'multiplier_Cement': 0.25, 'multiplier_Paper': 0.45, 'multiplier_Chemicals': 0.8, 'multiplier_Automotive': 0.30000000000000004, 'multiplier_Textiles': 0.15000000000000002}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:49:26,938] Trial 16 finished with value: -738250.3974542536 and parameters: {'multiplier_Steel': 0.75, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.8500000000000001, 'multiplier_Chemicals': 0.9500000000000001, 'multiplier_Automotive': 0.7000000000000001, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:49:50,471] Trial 17 finished with value: -722019.3324903811 and parameters: {'multiplier_Steel': 0.75, 'multiplier_Cement': 0.45, 'multiplier_Paper': 0.8500000000000001, 'multiplier_Chemicals': 0.9500000000000001, 'multiplier_Automotive': 0.7000000000000001, 'multiplier_Textiles': 0.35000000000000003}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:50:14,449] Trial 18 finished with value: -715486.0331641375 and parameters: {'multiplier_Steel': 0.75, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.9, 'multiplier_Chemicals': 0.9500000000000001, 'multiplier_Automotive': 0.7000000000000001, 'multiplier_Textiles': 0.55}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:50:38,547] Trial 19 finished with value: -712190.5031476162 and parameters: {'multiplier_Steel': 0.8500000000000001, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.8500000000000001, 'multiplier_Chemicals': 0.8500000000000001, 'multiplier_Automotive': 0.55, 'multiplier_Textiles': 0.6000000000000001}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:51:03,403] Trial 20 finished with value: -662158.8647587952 and parameters: {'multiplier_Steel': 0.05, 'multiplier_Cement': 0.15000000000000002, 'multiplier_Paper': 0.9500000000000001, 'multiplier_Chemicals': 0.35000000000000003, 'multiplier_Automotive': 0.25, 'multiplier_Textiles': 1.0}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:51:27,744] Trial 21 finished with value: -725819.9596071517 and parameters: {'multiplier_Steel': 0.4, 'multiplier_Cement': 0.65, 'multiplier_Paper': 0.7000000000000001, 'multiplier_Chemicals': 0.6000000000000001, 'multiplier_Automotive': 0.0, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:51:51,791] Trial 22 finished with value: -694426.1176274992 and parameters: {'multiplier_Steel': 0.55, 'multiplier_Cement': 0.75, 'multiplier_Paper': 0.1, 'multiplier_Chemicals': 0.7000000000000001, 'multiplier_Automotive': 0.05, 'multiplier_Textiles': 0.8500000000000001}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:52:15,901] Trial 23 finished with value: -715910.8487836138 and parameters: {'multiplier_Steel': 0.9, 'multiplier_Cement': 0.9, 'multiplier_Paper': 0.30000000000000004, 'multiplier_Chemicals': 0.1, 'multiplier_Automotive': 0.45, 'multiplier_Textiles': 0.45}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:52:41,051] Trial 24 finished with value: -727357.9771107025 and parameters: {'multiplier_Steel': 0.30000000000000004, 'multiplier_Cement': 0.30000000000000004, 'multiplier_Paper': 1.0, 'multiplier_Chemicals': 0.30000000000000004, 'multiplier_Automotive': 1.0, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:53:06,912] Trial 25 finished with value: inf and parameters: {'multiplier_Steel': 0.2, 'multiplier_Cement': 0.05, 'multiplier_Paper': 0.25, 'multiplier_Chemicals': 0.2, 'multiplier_Automotive': 0.9500000000000001, 'multiplier_Textiles': 0.5}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:53:32,305] Trial 26 finished with value: -714841.4873404636 and parameters: {'multiplier_Steel': 0.5, 'multiplier_Cement': 0.1, 'multiplier_Paper': 0.6000000000000001, 'multiplier_Chemicals': 0.25, 'multiplier_Automotive': 0.65, 'multiplier_Textiles': 0.25}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:53:58,851] Trial 27 finished with value: -686149.0434209611 and parameters: {'multiplier_Steel': 0.1, 'multiplier_Cement': 1.0, 'multiplier_Paper': 0.55, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.1, 'multiplier_Textiles': 0.75}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:54:27,075] Trial 28 finished with value: -732880.1251934634 and parameters: {'multiplier_Steel': 0.75, 'multiplier_Cement': 0.4, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.9500000000000001, 'multiplier_Automotive': 0.2, 'multiplier_Textiles': 0.2}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:54:54,370] Trial 29 finished with value: -733865.4190554664 and parameters: {'multiplier_Steel': 0.45, 'multiplier_Cement': 0.7000000000000001, 'multiplier_Paper': 0.75, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.5, 'multiplier_Textiles': 0.05}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:55:20,928] Trial 30 finished with value: -728217.4974470022 and parameters: {'multiplier_Steel': 0.75, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.8500000000000001, 'multiplier_Chemicals': 0.0, 'multiplier_Automotive': 0.7000000000000001, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:55:48,512] Trial 31 finished with value: -735387.3100973648 and parameters: {'multiplier_Steel': 0.15000000000000002, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.65, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:56:15,318] Trial 32 finished with value: -734587.8703862425 and parameters: {'multiplier_Steel': 0.15000000000000002, 'multiplier_Cement': 0.5, 'multiplier_Paper': 0.4, 'multiplier_Chemicals': 0.4, 'multiplier_Automotive': 0.65, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:56:43,735] Trial 33 finished with value: -738481.8765800388 and parameters: {'multiplier_Steel': 0.15000000000000002, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.45, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:57:09,630] Trial 34 finished with value: -742499.8366645309 and parameters: {'multiplier_Steel': 0.0, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 1.0, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:57:36,295] Trial 35 finished with value: -700081.7649366842 and parameters: {'multiplier_Steel': 0.0, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 1.0, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.9}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:58:03,089] Trial 36 finished with value: -718978.1342168647 and parameters: {'multiplier_Steel': 0.0, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.15000000000000002, 'multiplier_Automotive': 0.9, 'multiplier_Textiles': 0.30000000000000004}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:58:30,390] Trial 37 finished with value: -742763.0686146824 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.1}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:58:57,571] Trial 38 finished with value: -709434.8600264823 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.9500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.7000000000000001}. Best is trial 3 with value: -744069.1754942825.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:59:25,159] Trial 39 finished with value: -749314.5006006055 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 39 with value: -749314.5006006055.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 11:59:52,029] Trial 40 finished with value: -749314.5006006055 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 39 with value: -749314.5006006055.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:00:18,672] Trial 41 finished with value: -749314.5006006055 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.5, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 39 with value: -749314.5006006055.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:00:45,949] Trial 42 finished with value: -745982.5694132885 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.65, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 39 with value: -749314.5006006055.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:01:13,536] Trial 43 finished with value: -742534.797472455 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.8, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 39 with value: -749314.5006006055.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:01:40,872] Trial 44 finished with value: -762649.0712487927 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:02:08,342] Trial 45 finished with value: -745982.5694132885 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.65, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:02:36,128] Trial 46 finished with value: -762649.0712487927 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:03:02,824] Trial 47 finished with value: -762649.0712487927 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:03:29,279] Trial 48 finished with value: -762649.0712487927 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:03:54,947] Trial 49 finished with value: inf and parameters: {'multiplier_Steel': 0.7000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.55, 'multiplier_Automotive': 0.4, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:04:21,002] Trial 50 finished with value: inf and parameters: {'multiplier_Steel': 0.9500000000000001, 'multiplier_Cement': 0.35000000000000003, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.5, 'multiplier_Automotive': 0.15000000000000002, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:04:47,094] Trial 51 finished with value: -762649.0712487927 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:05:12,631] Trial 52 finished with value: inf and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.05, 'multiplier_Automotive': 0.8, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:05:38,361] Trial 53 finished with value: inf and parameters: {'multiplier_Steel': 0.65, 'multiplier_Cement': 0.6000000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.8500000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:06:03,873] Trial 54 finished with value: -715521.8564736465 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.75, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.65}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:06:29,458] Trial 55 finished with value: -733362.4800466805 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.8, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.4}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:06:55,060] Trial 56 finished with value: -693633.9033462018 and parameters: {'multiplier_Steel': 0.25, 'multiplier_Cement': 0.2, 'multiplier_Paper': 0.15000000000000002, 'multiplier_Chemicals': 0.65, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.8}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:07:20,834] Trial 57 finished with value: -703044.0608116114 and parameters: {'multiplier_Steel': 1.0, 'multiplier_Cement': 0.55, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.35000000000000003, 'multiplier_Textiles': 0.9500000000000001}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:07:47,180] Trial 58 finished with value: -751691.6172492059 and parameters: {'multiplier_Steel': 0.35000000000000003, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.35000000000000003, 'multiplier_Chemicals': 0.8, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:08:13,229] Trial 59 finished with value: -692144.3332130518 and parameters: {'multiplier_Steel': 0.35000000000000003, 'multiplier_Cement': 0.0, 'multiplier_Paper': 0.35000000000000003, 'multiplier_Chemicals': 0.8, 'multiplier_Automotive': 0.30000000000000004, 'multiplier_Textiles': 0.6000000000000001}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:08:38,818] Trial 60 finished with value: -735949.2110546328 and parameters: {'multiplier_Steel': 0.35000000000000003, 'multiplier_Cement': 0.25, 'multiplier_Paper': 0.35000000000000003, 'multiplier_Chemicals': 0.8, 'multiplier_Automotive': 0.55, 'multiplier_Textiles': 0.15000000000000002}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:09:04,881] Trial 61 finished with value: -758112.5517119643 and parameters: {'multiplier_Steel': 0.8500000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.2, 'multiplier_Chemicals': 0.8500000000000001, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:09:30,190] Trial 62 finished with value: -721985.8378111569 and parameters: {'multiplier_Steel': 0.8500000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.2, 'multiplier_Chemicals': 0.8500000000000001, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.55}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:09:55,882] Trial 63 finished with value: -718981.6879236912 and parameters: {'multiplier_Steel': 0.8500000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.45, 'multiplier_Chemicals': 0.35000000000000003, 'multiplier_Automotive': 0.25, 'multiplier_Textiles': 0.35000000000000003}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:10:21,406] Trial 64 finished with value: -681988.7750272271 and parameters: {'multiplier_Steel': 0.4, 'multiplier_Cement': 0.45, 'multiplier_Paper': 0.2, 'multiplier_Chemicals': 0.8500000000000001, 'multiplier_Automotive': 0.0, 'multiplier_Textiles': 1.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:10:46,804] Trial 65 finished with value: inf and parameters: {'multiplier_Steel': 0.05, 'multiplier_Cement': 0.15000000000000002, 'multiplier_Paper': 0.0, 'multiplier_Chemicals': 0.7000000000000001, 'multiplier_Automotive': 0.45, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:11:12,405] Trial 66 finished with value: -710348.331743635 and parameters: {'multiplier_Steel': 0.9, 'multiplier_Cement': 0.9, 'multiplier_Paper': 0.9, 'multiplier_Chemicals': 0.6000000000000001, 'multiplier_Automotive': 0.05, 'multiplier_Textiles': 0.45}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:11:38,371] Trial 67 finished with value: -722450.9728590057 and parameters: {'multiplier_Steel': 0.55, 'multiplier_Cement': 0.65, 'multiplier_Paper': 0.9500000000000001, 'multiplier_Chemicals': 0.30000000000000004, 'multiplier_Automotive': 1.0, 'multiplier_Textiles': 0.25}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:12:04,341] Trial 68 finished with value: inf and parameters: {'multiplier_Steel': 0.30000000000000004, 'multiplier_Cement': 0.75, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.1, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:12:29,710] Trial 69 finished with value: -704401.5274488208 and parameters: {'multiplier_Steel': 0.5, 'multiplier_Cement': 0.30000000000000004, 'multiplier_Paper': 0.7000000000000001, 'multiplier_Chemicals': 0.25, 'multiplier_Automotive': 0.9500000000000001, 'multiplier_Textiles': 0.5}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:12:55,851] Trial 70 finished with value: -671273.3390416321 and parameters: {'multiplier_Steel': 0.1, 'multiplier_Cement': 0.05, 'multiplier_Paper': 0.1, 'multiplier_Chemicals': 0.2, 'multiplier_Automotive': 0.5, 'multiplier_Textiles': 0.8500000000000001}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:13:21,440] Trial 71 finished with value: -729209.3479833752 and parameters: {'multiplier_Steel': 0.2, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 1.0, 'multiplier_Chemicals': 0.0, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:13:47,649] Trial 72 finished with value: -697353.8969810783 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.55, 'multiplier_Chemicals': 0.8, 'multiplier_Automotive': 0.1, 'multiplier_Textiles': 0.75}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:14:14,763] Trial 73 finished with value: inf and parameters: {'multiplier_Steel': 0.45, 'multiplier_Cement': 0.4, 'multiplier_Paper': 0.25, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.2, 'multiplier_Textiles': 0.2}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:14:44,274] Trial 74 finished with value: -747470.6361322942 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 1.0, 'multiplier_Paper': 0.30000000000000004, 'multiplier_Chemicals': 0.4, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.05}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:15:11,620] Trial 75 finished with value: -747889.2812780046 and parameters: {'multiplier_Steel': 0.8500000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.6000000000000001, 'multiplier_Chemicals': 0.8500000000000001, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:15:37,578] Trial 76 finished with value: inf and parameters: {'multiplier_Steel': 0.35000000000000003, 'multiplier_Cement': 0.7000000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.15000000000000002, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:16:04,573] Trial 77 finished with value: inf and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.1, 'multiplier_Paper': 0.35000000000000003, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:16:31,329] Trial 78 finished with value: -733209.3292928158 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.2, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.4, 'multiplier_Textiles': 0.30000000000000004}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:16:58,124] Trial 79 finished with value: -700224.3057871115 and parameters: {'multiplier_Steel': 0.7000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.75, 'multiplier_Chemicals': 0.75, 'multiplier_Automotive': 0.8, 'multiplier_Textiles': 0.9}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:17:25,435] Trial 80 finished with value: -703864.229472544 and parameters: {'multiplier_Steel': 0.65, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.05, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.7000000000000001}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:17:52,290] Trial 81 finished with value: -742534.797472455 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.8, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:18:18,227] Trial 82 finished with value: -762649.0712487927 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:18:43,177] Trial 83 finished with value: -762649.0712487927 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.6000000000000001, 'multiplier_Textiles': 0.0}. Best is trial 44 with value: -762649.0712487927.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:19:08,815] Trial 84 finished with value: -762979.9148946183 and parameters: {'multiplier_Steel': 0.9500000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.55, 'multiplier_Automotive': 0.8500000000000001, 'multiplier_Textiles': 0.0}. Best is trial 84 with value: -762979.9148946183.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:19:34,341] Trial 85 finished with value: inf and parameters: {'multiplier_Steel': 0.9500000000000001, 'multiplier_Cement': 0.6000000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.55, 'multiplier_Automotive': 0.8500000000000001, 'multiplier_Textiles': 0.0}. Best is trial 84 with value: -762979.9148946183.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:20:00,189] Trial 86 finished with value: -708490.4379102698 and parameters: {'multiplier_Steel': 0.9500000000000001, 'multiplier_Cement': 0.35000000000000003, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.55, 'multiplier_Automotive': 0.8500000000000001, 'multiplier_Textiles': 0.8}. Best is trial 84 with value: -762979.9148946183.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:20:25,419] Trial 87 finished with value: -719998.5541864578 and parameters: {'multiplier_Steel': 0.6000000000000001, 'multiplier_Cement': 0.8, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.8500000000000001, 'multiplier_Textiles': 0.65}. Best is trial 84 with value: -762979.9148946183.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:20:51,169] Trial 88 finished with value: inf and parameters: {'multiplier_Steel': 0.25, 'multiplier_Cement': 0.2, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.55, 'multiplier_Automotive': 0.15000000000000002, 'multiplier_Textiles': 0.0}. Best is trial 84 with value: -762979.9148946183.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:21:17,272] Trial 89 finished with value: -763632.6367484378 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.0}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:21:42,720] Trial 90 finished with value: -733616.3422805872 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.55, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.4}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:22:08,703] Trial 91 finished with value: -763632.6367484378 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.0}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:22:33,352] Trial 92 finished with value: -763632.6367484378 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.0}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:22:58,699] Trial 93 finished with value: -708513.860839251 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.9500000000000001}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:23:24,175] Trial 94 finished with value: inf and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.0, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.5, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.0}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:23:49,761] Trial 95 finished with value: -719194.1596426796 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.25, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.6000000000000001}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:24:14,949] Trial 96 finished with value: -735991.001359567 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.65, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.35000000000000003}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:24:40,770] Trial 97 finished with value: -749463.0413184877 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.45, 'multiplier_Paper': 0.15000000000000002, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.75, 'multiplier_Textiles': 0.15000000000000002}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:25:06,585] Trial 98 finished with value: -762027.1082824329 and parameters: {'multiplier_Steel': 0.9500000000000001, 'multiplier_Cement': 0.8500000000000001, 'multiplier_Paper': 0.05, 'multiplier_Chemicals': 0.9, 'multiplier_Automotive': 0.35000000000000003, 'multiplier_Textiles': 0.0}. Best is trial 89 with value: -763632.6367484378.
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# [I 2024-11-15 12:25:32,085] Trial 99 finished with value: -712329.3111350355 and parameters: {'multiplier_Steel': 0.8, 'multiplier_Cement': 0.65, 'multiplier_Paper': 0.0, 'multiplier_Chemicals': 0.35000000000000003, 'multiplier_Automotive': 0.30000000000000004, 'multiplier_Textiles': 0.55}. Best is trial 89 with value: -763632.6367484378.
# Optimal free_emission_multipliers:
# Steel: 0.8
# Cement: 0.8500000000000001
# Paper: 0.05
# Chemicals: 0.9
# Automotive: 0.75
# Textiles: 0.0
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# No solution found
# Optimal solution found
# Firm S1_F1 has output 324.2090854190903 and emission 322.15667519002074
# Firm S1_F2 has output 324.2090854190901 and emission 322.5168204315117
# Firm S1_F3 has output 324.2090854190902 and emission 322.7194072900629
# Firm S1_F4 has output 324.2090854190902 and emission 322.47608981369075
# Firm S1_F5 has output 324.2090854190902 and emission 322.21177413862006
# Firm S2_F1 has output 486.22589497561376 and emission 484.7355470352176
# Firm S2_F2 has output 486.22589497561364 and emission 484.34649666795724
# Firm S2_F3 has output 486.22589497561364 and emission 483.71405943372264
# Firm S2_F4 has output 486.22589497561364 and emission 484.1193628998892
# Firm S2_F5 has output 486.2258949756138 and emission 483.9325527424143
# Firm S3_F1 has output 619.9224386083678 and emission 617.295763048605
# Firm S3_F2 has output 619.9224386083679 and emission 617.5733158090355
# Firm S3_F3 has output 619.9224386083679 and emission 618.0027092086351
# Firm S3_F4 has output 619.9224386083678 and emission 617.3526151571953
# Firm S3_F5 has output 619.9224386083678 and emission 618.1494999080932
# Firm S4_F1 has output 274.67787303768233 and emission 272.88684201052473
# Firm S4_F2 has output 274.67787303768233 and emission 273.15914304845455
# Firm S4_F3 has output 274.6778730376824 and emission 273.01362601530064
# Firm S4_F4 has output 274.6778730376824 and emission 273.3461529959953
# Firm S4_F5 has output 274.67787303768233 and emission 273.39296131213536
# Firm S5_F1 has output 244.31927834185342 and emission 242.63682222696713
# Firm S5_F2 has output 244.31927834185345 and emission 243.02664949000697
# Firm S5_F3 has output 244.3192783418534 and emission 242.7596819166183
# Firm S5_F4 has output 244.3192783418534 and emission 243.04037325723974
# Firm S5_F5 has output 244.31927834185345 and emission 243.07758957264483
# Firm S6_F1 has output 884.1395898629024 and emission 881.5129143031394
# Firm S6_F2 has output 884.1395898629024 and emission 881.7904670635703
# Firm S6_F3 has output 884.1395898629024 and emission 882.2198604631694
# Firm S6_F4 has output 884.1395898629025 and emission 881.5697664117276
# Firm S6_F5 has output 884.1395898629024 and emission 882.3666511626278
# Permit price: 26.951624608225856
# Maximum Consumer Surplus: 763632.636748438
